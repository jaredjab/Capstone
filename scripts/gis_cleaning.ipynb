# %%
import pandas as pd

# %%
bounds = pd.read_csv('../data/national-park-service/gis/nps_boundaries.csv')

# %%
bounds.head()
# Out:
#    OBJECTID          CreationDate         Creator              EditDate  \
# 0         1  4/2/2024 10:10:33 AM  NPS_WASO_LANDS  4/2/2024 10:10:33 AM
# 1         2  4/2/2024 10:10:33 AM  NPS_WASO_LANDS  4/2/2024 10:10:33 AM
# 2         3  4/2/2024 10:10:33 AM  NPS_WASO_LANDS  4/2/2024 10:10:33 AM
# 3         4  4/2/2024 10:10:33 AM  NPS_WASO_LANDS  4/2/2024 10:10:33 AM
# 4         5  4/2/2024 10:10:33 AM  NPS_WASO_LANDS  4/2/2024 10:10:33 AM
#
#            Editor                              GlobalID  AreaID UNIT_CODE  \
# 0  NPS_WASO_LANDS  5a464c42-3020-482c-b3be-26a3646d35ef     296      GICL
# 1  NPS_WASO_LANDS  32f83fda-cf15-46f4-8849-42ee039b3829     134      ASIS
# 2  NPS_WASO_LANDS  beb1cc79-f8d9-47a7-b08b-5ca28789fea3     435      VALL
# 3  NPS_WASO_LANDS  55da3854-c357-4d0e-b33e-6dda7a571678     157      PETE
# 4  NPS_WASO_LANDS  c9887674-6260-4a49-bbad-5ea7d890e347      59      DINO
#
#                                            GIS_Notes  \
# ...

# %%
bounds = bounds.loc[bounds.UNIT_TYPE == 'National Park']
bounds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62 entries, 8 to 397
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OBJECTID       62 non-null     int64
#  1   CreationDate   62 non-null     object
#  2   Creator        62 non-null     object
#  3   EditDate       62 non-null     object
#  4   Editor         62 non-null     object
#  5   GlobalID       62 non-null     object
#  6   AreaID         62 non-null     int64
#  7   UNIT_CODE      62 non-null     object
#  8   GIS_Notes      62 non-null     object
#  9   UNIT_NAME      62 non-null     object
#  10  DATE_EDIT      62 non-null     object
#  11  STATE          62 non-null     object
#  12  REGION         62 non-null     object
#  13  GNIS_ID        62 non-null     object
#  14  UNIT_TYPE      62 non-null     object
#  15  CREATED_BY     62 non-null     object
#  16  METADATA       62 non-null     object
# ...
