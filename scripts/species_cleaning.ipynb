# %%
import pandas as pd
import re

# %%
np_data = pd.read_csv('../data/np_data.csv')

# %%
np_data.head(1)
# Out:
#   park_name date_established  \
# 0    Acadia       1919-02-26
#
#                                          description  area_acres area_km2  \
# 0  Covering most of Mount Desert Island and other...     49071.4    198.6
#
#    state  recreational_visits  non_recreational_visits  recreational_hours  \
# 0  Maine            3879890.0                  47100.0          25804425.0
#
#    non_recreational_hours  tent_overnights  rv_overnights  \
# 0                 47100.0         120615.0        49074.0
#
#    backcountry_overnights
# 0                  1570.0

# %%
parks = np_data.park_name.to_list()

# %%
parks[0:5]
# Out:
# ['Acadia', 'American Samoa', 'Arches', 'Badlands', 'Big Bend']

# %%
parks = parks[1:]
parks[0:5]
# Out:
# ['American Samoa', 'Arches', 'Badlands', 'Big Bend', 'Biscayne']

# %%
acadia = pd.read_csv('../data/national-park-service/np-species/acadia.csv')

# %%
acadia = acadia.drop(columns=['Park Code', 'Category Sort', 'Order'
                     , 'Family', 'Taxon Code', 'TSN'
                     , 'Taxon Record Status', 'Scientific Name'
                     , 'Synonyms'])

# %%
acadia = acadia.rename(columns={'Park Name':'park_name'
                      ,'Category':'category'
                      ,'Common Names':'common_names'
                      ,'Occurrence':'occurrence'})

# %%
acadia
# Out:
#                  park_name        category  \
# 0     Acadia National Park          Mammal
# 1     Acadia National Park          Mammal
# 2     Acadia National Park          Mammal
# 3     Acadia National Park          Mammal
# 4     Acadia National Park          Mammal
# ...                    ...             ...
# 1165  Acadia National Park  Vascular Plant
# 1166  Acadia National Park  Vascular Plant
# 1167  Acadia National Park  Vascular Plant
# 1168  Acadia National Park  Vascular Plant
# 1169  Acadia National Park  Vascular Plant
#
#                                            common_names occurrence
# 0                                                 Moose    Present
# 1     Northern White-tailed Deer, Virginia Deer, Whi...    Present
# 2                                Coyote, Eastern Coyote    Present
# 3     Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...    Present
# 4                  Bay Lynx, Bobcat, Red Lynx, Wild Cat    Present
# ...                                                 ...        ...
# 1165                                     Hedge Bindweed    Present
# 1166                           Common Dodder, Love Vine    Present
# 1167                                  Deadly Nightshade    Present
# 1168                                        Buffalo Bur    Present
# 1169                         Virginia Creeper, Woodbine    Present
#
# [1170 rows x 4 columns]

# %%
re.findall(r'(^.*) National Park', acadia.park_name[0])
# Out:
# ['Acadia']

# %%
acadia.park_name = acadia.park_name.apply(lambda park: re.findall(r'(^.*) National Park', park)[0])

# %%
acadia = acadia.loc[acadia.occurrence == 'Present']

# %%
acadia = acadia.drop(columns='occurrence')

# %%
acadia
# Out:
#      park_name        category  \
# 0       Acadia          Mammal
# 1       Acadia          Mammal
# 2       Acadia          Mammal
# 3       Acadia          Mammal
# 4       Acadia          Mammal
# ...        ...             ...
# 1165    Acadia  Vascular Plant
# 1166    Acadia  Vascular Plant
# 1167    Acadia  Vascular Plant
# 1168    Acadia  Vascular Plant
# 1169    Acadia  Vascular Plant
#
#                                            common_names
# 0                                                 Moose
# 1     Northern White-tailed Deer, Virginia Deer, Whi...
# 2                                Coyote, Eastern Coyote
# 3     Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
# 4                  Bay Lynx, Bobcat, Red Lynx, Wild Cat
# ...                                                 ...
# 1165                                     Hedge Bindweed
# 1166                           Common Dodder, Love Vine
# 1167                                  Deadly Nightshade
# 1168                                        Buffalo Bur
# 1169                         Virginia Creeper, Woodbine
#
# [1169 rows x 3 columns]

# %%
def speciesDf(base_df = acadia):
    biodiversity = base_df
    for park in parks:
        park = park.lower()
        try:
            df = pd.read_csv(f'../data/national-park-service/np-species/{park}.csv', encoding='latin-1')
            print(f'------{park}.csv was read in.------')
        except Exception as error:
            continue
            print()
            print(f'! ERROR - {park}.csv was NOT read in. !')
            print(error)
            print()
        df = df.drop(columns=['Park Code', 'Category Sort', 'Order'
                            , 'Family', 'Taxon Code', 'TSN'
                            , 'Taxon Record Status', 'Scientific Name'
                            , 'Synonyms'])
        df = df.rename(columns={'Park Name':'park_name'
                               ,'Category':'category'
                               ,'Common Names':'common_names'
                               ,'Occurrence':'occurrence'})
        df.park_name = df.park_name.apply(lambda name: re.findall(r'(^.*) National Park', name)[0])
        df = df.loc[df.occurrence == 'Present']
        df = df.drop(columns='occurrence')
        frames = [biodiversity, df]
        biodiversity = pd.concat(frames)
    return biodiversity

# %%
biodiversity = speciesDf()
# Out:
# ------arches.csv was read in.------
# ------badlands.csv was read in.------
# ------big bend.csv was read in.------
# ------biscayne.csv was read in.------
# ------black canyon of the gunnison.csv was read in.------
# ------bryce canyon.csv was read in.------
# ------canyonlands.csv was read in.------
# ------capitol reef.csv was read in.------
# ------carlsbad caverns.csv was read in.------
# ------channel islands.csv was read in.------
# ------congaree.csv was read in.------
# ------crater lake.csv was read in.------
# ------cuyahoga valley.csv was read in.------
# ------death valley.csv was read in.------
# ------denali.csv was read in.------
# ------dry tortugas.csv was read in.------
# ------everglades.csv was read in.------
# ------gates of the arctic.csv was read in.------
# ------glacier.csv was read in.------
# ------glacier bay.csv was read in.------
# ------grand canyon.csv was read in.------
# ------grand teton.csv was read in.------
# ------great basin.csv was read in.------
# ------great sand dunes.csv was read in.------
# ------great smoky mountains.csv was read in.------
# ------guadalupe mountains.csv was read in.------
# ------hot springs.csv was read in.------
# ------indiana dunes.csv was read in.------
# ------isle royale.csv was read in.------
# ------joshua tree.csv was read in.------
# ------katmai.csv was read in.------
# ------kenai fjords.csv was read in.------
# ------kobuk valley.csv was read in.------
# ------lake clark.csv was read in.------
# ------lassen volcanic.csv was read in.------
# ------mammoth cave.csv was read in.------
# ------mesa verde.csv was read in.------
# ------mount rainier.csv was read in.------
# ------new river gorge.csv was read in.------
# ------north cascades.csv was read in.------
# ------olympic.csv was read in.------
# ------petrified forest.csv was read in.------
# ------pinnacles.csv was read in.------
# ------redwood.csv was read in.------
# ------rocky mountain.csv was read in.------
# ------saguaro.csv was read in.------
# ------shenandoah.csv was read in.------
# ------theodore roosevelt.csv was read in.------
# ------virgin islands.csv was read in.------
# ------voyageurs.csv was read in.------
# ------white sands.csv was read in.------
# ------wind cave.csv was read in.------
# ------yellowstone.csv was read in.------
# ------yosemite.csv was read in.------
# ------zion.csv was read in.------

# %%
biodiversity
# Out:
#      park_name        category  \
# 0       Acadia          Mammal
# 1       Acadia          Mammal
# 2       Acadia          Mammal
# 3       Acadia          Mammal
# 4       Acadia          Mammal
# ...        ...             ...
# 1433      Zion  Vascular Plant
# 1434      Zion  Vascular Plant
# 1435      Zion  Vascular Plant
# 1436      Zion  Vascular Plant
# 1437      Zion  Vascular Plant
#
#                                            common_names Record Status  \
# 0                                                 Moose           NaN
# 1     Northern White-tailed Deer, Virginia Deer, Whi...           NaN
# 2                                Coyote, Eastern Coyote           NaN
# 3     Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...           NaN
# 4                  Bay Lynx, Bobcat, Red Lynx, Wild Cat           NaN
# ...                                                 ...           ...
# 1433                                cut-leaf nightshade           NaN
# 1434                                       canyon grape           NaN
# 1435                                         wine grape           NaN
# 1436                                      creosote bush           NaN
# 1437                                      puncture vine           NaN
#
#      Occurrence Tags Nativeness Nativeness Tags Abundance
# 0                NaN        NaN             NaN       NaN
# 1                NaN        NaN             NaN       NaN
# 2                NaN        NaN             NaN       NaN
# 3                NaN        NaN             NaN       NaN
# 4                NaN        NaN             NaN       NaN
# ...              ...        ...             ...       ...
# 1433             NaN        NaN             NaN       NaN
# 1434             NaN        NaN             NaN       NaN
# 1435             NaN        NaN             NaN       NaN
# 1436             NaN        NaN             NaN       NaN
# 1437             NaN        NaN             NaN       NaN
#
# [94911 rows x 8 columns]

# %%
biodiversity.park_name.nunique()
# Out:
# 56

# %%
biodiversity = biodiversity.drop(columns=['Record Status', 'Occurrence Tags'
                          ,'Nativeness', 'Nativeness Tags', 'Abundance'])

# %%
biodiversity
# Out:
#      park_name        category  \
# 0       Acadia          Mammal
# 1       Acadia          Mammal
# 2       Acadia          Mammal
# 3       Acadia          Mammal
# 4       Acadia          Mammal
# ...        ...             ...
# 1433      Zion  Vascular Plant
# 1434      Zion  Vascular Plant
# 1435      Zion  Vascular Plant
# 1436      Zion  Vascular Plant
# 1437      Zion  Vascular Plant
#
#                                            common_names
# 0                                                 Moose
# 1     Northern White-tailed Deer, Virginia Deer, Whi...
# 2                                Coyote, Eastern Coyote
# 3     Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
# 4                  Bay Lynx, Bobcat, Red Lynx, Wild Cat
# ...                                                 ...
# 1433                                cut-leaf nightshade
# 1434                                       canyon grape
# 1435                                         wine grape
# 1436                                      creosote bush
# 1437                                      puncture vine
#
# [94911 rows x 3 columns]

# %%
biodiversity.to_csv('../data/biodiversity.csv', index=False)
