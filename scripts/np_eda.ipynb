# %%
import pandas as pd
import seaborn as sns
import numpy as np
from datetime import datetime as dt

# %%
np = pd.read_csv('../data/np_data.csv')

# %%
np.date_established = pd.to_datetime(np.date_established)

# %%
np.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   park_name                65 non-null     object
#  1   date_established         63 non-null     datetime64[ns]
#  2   description              63 non-null     object
#  3   area_acres               63 non-null     float64
#  4   area_km2                 63 non-null     object
#  5   state                    63 non-null     object
#  6   recreational_visits      54 non-null     float64
#  7   non_recreational_visits  54 non-null     float64
#  8   recreational_hours       54 non-null     float64
#  9   non_recreational_hours   54 non-null     float64
#  10  tent_overnights          54 non-null     float64
#  11  rv_overnights            54 non-null     float64
#  12  backcountry_overnights   54 non-null     float64
# dtypes: datetime64[ns](1), float64(8), object(4)
# ...

# %%
np.head(1)
# Out:
#   park_name date_established  \
# 0    Acadia       1919-02-26
#
#                                          description  area_acres area_km2  \
# 0  Covering most of Mount Desert Island and other...     49071.4    198.6
#
#    state  recreational_visits  non_recreational_visits  recreational_hours  \
# 0  Maine            3879890.0                  47100.0          25804425.0
#
#    non_recreational_hours  tent_overnights  rv_overnights  \
# 0                 47100.0         120615.0        49074.0
#
#    backcountry_overnights
# 0                  1570.0

# %%
np.tail(1)
# Out:
#            park_name date_established description  area_acres area_km2 state  \
# 64  Hawaii Volcanoes              NaT         NaN         NaN      NaN   NaN
#
#     recreational_visits  non_recreational_visits  recreational_hours  \
# 64            1620294.0                1878799.0          10263418.0
#
#     non_recreational_hours  tent_overnights  rv_overnights  \
# 64                620005.0            958.0            5.0
#
#     backcountry_overnights
# 64                  3704.0

# %%
np.describe()
# Out:
#           date_established    area_acres  recreational_visits  \
# count                   63  6.300000e+01         5.400000e+01
# mean   1957-08-17 00:00:00  8.326318e+05         1.644748e+06
# min    1872-03-01 00:00:00  1.928300e+02         1.761600e+04
# 25%    1924-08-29 12:00:00  5.859319e+04         3.978670e+05
# 50%    1968-10-02 00:00:00  2.182224e+05         7.958070e+05
# 75%    1980-12-02 00:00:00  7.156988e+05         2.492542e+06
# max    2020-12-27 00:00:00  8.323146e+06         1.329765e+07
# std                    NaN  1.632137e+06         2.121811e+06
#
#        non_recreational_visits  recreational_hours  non_recreational_hours  \
# count             5.400000e+01        5.400000e+01            5.400000e+01
# mean              4.380271e+05        1.307457e+07            3.063926e+05
# min               0.000000e+00        2.261490e+05            0.000000e+00
# 25%               2.350000e+01        1.813989e+06            3.000000e+01
# ...

# %%
sns.scatterplot(data=np
           ,x='date_established'
           ,y='recreational_hours');

# %%
sns.lineplot(data=np
           ,x='area_acres'
           ,y='recreational_hours');

# %%
sns.barplot(data=np
           ,x='state'
           ,y='recreational_visits');
# Out:
# C:\Users\Jab\anaconda3\Lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# C:\Users\Jab\anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,

# %%
np.corr(numeric_only=True)
# Out:
#                          area_acres  recreational_visits  \
# area_acres                 1.000000             0.141852
# recreational_visits        0.141852             1.000000
# non_recreational_visits    0.036650             0.729249
# recreational_hours         0.349992             0.849735
# non_recreational_hours     0.099489             0.714645
# tent_overnights            0.245397             0.663469
# rv_overnights              0.323017             0.677554
# backcountry_overnights     0.277750             0.418559
#
#                          non_recreational_visits  recreational_hours  \
# area_acres                              0.036650            0.349992
# recreational_visits                     0.729249            0.849735
# non_recreational_visits                 1.000000            0.557016
# recreational_hours                      0.557016            1.000000
# non_recreational_hours                  0.776459            0.649803
# ...

# %%
# FIXME compare with each park's 2022 yelp rating and biodiversity score

# %%
acadia_species = pd.read_csv('../data/national-park-service/np-species/acadia_species.csv')

# %%
acadia_species
# Out:
#      Park Code             Park Name        Category  Category Sort  \
# 0         ACAD  Acadia National Park          Mammal              1
# 1         ACAD  Acadia National Park          Mammal              1
# 2         ACAD  Acadia National Park          Mammal              1
# 3         ACAD  Acadia National Park          Mammal              1
# 4         ACAD  Acadia National Park          Mammal              1
# ...        ...                   ...             ...            ...
# 1165      ACAD  Acadia National Park  Vascular Plant              6
# 1166      ACAD  Acadia National Park  Vascular Plant              6
# 1167      ACAD  Acadia National Park  Vascular Plant              6
# 1168      ACAD  Acadia National Park  Vascular Plant              6
# 1169      ACAD  Acadia National Park  Vascular Plant              6
#
#              Order          Family  Taxon Code     TSN Taxon Record Status  \
# ...
