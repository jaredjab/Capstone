# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
acreage = pd.read_csv('../data/final/acreage.csv')
biodiversity = pd.read_csv('../data/final/biodiversity.csv')
climate = pd.read_csv('../data/final/climate.csv')
fees = pd.read_csv('../data/final/fees.csv')
general = pd.read_csv('../data/final/general.csv')
visitation = pd.read_csv('../data/final/visitation.csv')
# Out:
# C:\Users\Jab\AppData\Local\Temp\ipykernel_1704\4005627502.py:6: DtypeWarning: Columns (12,16,29,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   visitation = pd.read_csv('../data/final/visitation.csv')

# %%
climate.describe()
# Out:
#             month  precipitation_in     snow_in  avg_temp_f  max_temp_f  \
# count  756.000000        744.000000  492.000000  756.000000  756.000000
# mean     6.500000          2.864516    4.315447   52.124074   63.155291
# std      3.454338          2.885260   10.497115   19.624710   20.340723
# min      1.000000          0.010000    0.000000   -9.900000   -0.500000
# 25%      3.750000          0.910000    0.000000   38.400000   48.700000
# 50%      6.500000          1.950000    0.000000   53.500000   64.650000
# 75%      9.250000          3.672500    3.725000   67.225000   79.025000
# max     12.000000         17.780000   90.600000  104.200000  117.400000
#
#        min_temp_f
# count  756.000000
# mean    41.087831
# std     19.469636
# min    -19.300000
# 25%     28.750000
# 50%     41.350000
# 75%     54.000000
# max     91.000000

# %%
sns.lineplot(climate
            ,x='month'
            ,y='avg_temp_f'
            ,hue='park_name'
            ,legend=False);

# %%
sns.lineplot(climate
            ,x='month'
            ,y='precipitation_in'
            ,hue='park_name'
            ,legend=False);

# %%
sns.lineplot(climate
            ,x='month'
            ,y='snow_in'
            ,hue='park_name'
            ,legend=False);
